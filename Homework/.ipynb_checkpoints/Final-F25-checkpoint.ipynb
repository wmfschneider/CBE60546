# %% [markdown]
# # Advanced Chemical Reaction Engineering (CBE 60546)
# ## Final Exam
# ## Due December 12 - 13, 2025

# %% [markdown]
# YOU HAVE UNTIL 7:30 PM, DECEMBER 13, 2025, TO COMPLETE THIS EXAM. RETURN VIA EMAIL BY THEN TO WSCHNEIDER@ND.EDU AND SLEE75@ND.EDU.
#
# YOU MUST WORK INDEPENDENTLY. YOU CAN USE THE EXAMPLES NOTEBOOK SHARED FROM CLASS AND YOUR (NOT HENRY'S!) SOLUTIONS TO YOUR HOMEWORKS BUT NO OTHER OUTSIDE RESOURCES, INCLUDING AI OR WEB SEARCHES OR TEXTBOOK. CALCULATIONS ARE REQUIRED, SO I RECOMMEND WORKING IN A PYTHON NOTEBOOK WITH PLENTY OF PAPER AT YOUR SIDE. SUBMIT YOUR ANSWERS AT A SINGLE DOCUMENT, EITHER IPYNB OR PDF FORMAT.
#
# See Examples code at https://github.com/wmfschneider/CBE60546/blob/main/Resources/Examples.ipynb.

# %% [markdown]
# # Reaction to Reactor Engineering
# You are working on a heterogeneous, catalyzed, gas-phase reaction that converts a reactant A to product P (an isomerization). Your goals are:
#
# 1. Determine the intrinsic rate law and mechanism
# 2. Determine the fundamental parameters of that rate law
# 3. Diagnose and quantify any mass transfer limitations to the reaction
# 4. Anticipate the consequences of non-isothermal operation of a reactor

# %% [markdown]
# ### You collect the following half-life data in a batch reactor at very low initial partial pressure of A in nitrogen, over a catalyst powder. What can you infer about the apparent reaction kinetics from this data?
#
# | Temperature (K) | $P_\text{A0}$ (bar) | $t_{1/2}$ (min) |
# |-----------------|-------------------|-----------------|
# |             350 |   0.005            |         8.80    |
# |             350 |   0.010            |         8.80    |
# |             370 |   0.005            |         1.39    |
# |             390 |   0.005            |         0.26    |

# %%
# Answer here

# %% [markdown]
# ### You next collect data on the reaction in an isothermal, 1 liter CSTR at $T=370$ K, 2 bar total pressure, and various volumetric flow rates, using the same powder catalyst as in the batch reactor. Determine the pseudo-homogeneous reaction rate (in bar/min) at each condition.
#
# | $P_\text{A0}$ (bar) | $v_0$ (l/min) | $P_\text{A}$ (bar) |
# |-------------------|---------------|------------------|
# |              0.20 |    0.33       |           0.10 |
# |              0.60 |    0.33       |           0.40 |
# |              1.00 |    0.40       |           0.80 |
# |              2.00 |    0.80       |           1.80 |

# %%
# Answer here

# %% [markdown]
# ### Are the CSTR kinetics consistent with what you learned from the batch reactor? Why or why not?

# %%
# Answer here

# %% [markdown]
# ### You hypothesize that the reaction follows a Langmuir-Hinshelwood mechanism. Propose a candidate mechanism and derive a rate law based on that proposal. (Best to do this on a piece of paper and paste the answer into your notebook!)

# %%
# Answer here

# %% [markdown]
# ### Verify that your proposed model fits the CSTR rate data and extract values for the constants in your model

# %%
# Answer here

# %% [markdown]
# ### You figure out that an inhibitor I irreversibly binds to the catalyst sites and decide to use this discovery to titrate and count the active sites in your catalyst. You collect the following data in the same CSTR, packing it with 10 g of catalyst powder. Determine the number of sites per liter of catalyst.
#
# | I added ($\micro$mol) | $-r_\text{A}$ ( bar/min) |
# |-----------------------|--------------------------|
# |    0      | 0.091 |
# | 50        | 0.073 |
# | 100 | 0.055  |
# | 150 | 0.036   |

# %%
# Answer here

# %% [markdown]
# ### Now you need to translate your discoveries to practice. You prepare catalyst pellets of radius 0.15 cm, load the CSTR with 10 g of pellets, and measure the rate at 0.8 bar outlet A and 370 K. You obtain a rate of 0.016 bar/min, compared to 0.080 bar/min on the powder. Estimate the effective diffusivity of A in the pellets assuming that the reaction can be approximated as first order in A.

# %%
# Answer here
# Out:
# De =1.00e-05 cm2/min

# %% [markdown]
# ### Sketch the concentration of *product* P vs distance from center of particle. You can assume ideal gas behavior. (*Hint* What does mass balance say about the relationship between the concentrations of A and P in the particle?)

# %%
# Answer here

# %% [markdown]
# ### Based on reactor data, is first-order a good approximation at 0.8 bar? If not, what would be a better one?

# %%
# Answer here

# %% [markdown]
# ### Do you think the first-order approximation over- or under-estimates the particle effectiveness?

# %%
# Answer here

# %% [markdown]
# ### If you were to measure the apparent activation energy over the catalyst pellets, what do you think you would find?

# %%
# Answer here

# %% [markdown]
# ### The isomerization reaction is exothermic by 150 kJ/mol, and you feed the reactor 0.8 bar A in 7.2 bar diluent at 370 K. The heat capacity of the feed gas is about 30 J/mol K. What is the maximum temperature the reactor might reach if it was insulated and adiabatic?

# %%
# Answer here

# %% [markdown]
# ### The equilibrium constant of the reaction at 370 K is 0.5. What is the maximum possible conversion if the reactor is run adiabatically?

# %%
# Answer here

# %% [markdown]
# ### Based on your answer, is it wiser to run the reaction isothermally or adiabatically? If isothermally, how much cooling would you need to do?

# %%
# Answer here

# %% [markdown]
# ### One of the major goals of the course is to prepare you for chemical engineering research. In a short paragraph, share which research group you are joining, what project you will work on (to the extent you know it), and how the course topics could apply to your or other's research in your group.

# %%
# Answer here

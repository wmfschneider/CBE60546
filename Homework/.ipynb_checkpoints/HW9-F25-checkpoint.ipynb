# %% [markdown]
# # Advanced Chemical Reaction Engineering (CBE 60546)
# ## Homework 9
# ## Due December 11, 2025

# %% [markdown]
# Carefully and neatly document your answers. Use Jupyter/Collab for all plots. See sample code at https://github.com/wmfschneider/CBE60546/blob/main/Resources/Examples.ipynb.

# %% [markdown]
# # Pushing to the limit
# Consider the liquid-phase, autocatalytic reaction
#
# $$\ce{2 A -> B},\ \ \ \ r=kC_A C_B\ \ \ \ k(300\text{ K}) = 0.5 \text{M}^{-1} \text{s}^{-1}$$
#
# The reaction enthalpy and volumetric heat capacity are  $\Delta H_\text{rxn} = -200$ kJ/mol and $\rho \bar{C}_p = 4000$ J/l/K, respectively, and are roughly temperature-independent. The reaction follows Arrhenius kinetics and the rate constant at 310 K is twice that of 300 K. You have a feed containing 0.2 M B and 2.0 M A.

# %% [markdown]
# ### Determine the reaction activation energy and prefactor.

# %%
# Answer here

# %% [markdown]
# ### Suppose you run the reaction in an isothermal PFR at 300 K. Plot conversion vs reactor space time.

# %%
# Answer here

# %% [markdown]
# ### What space time is necessary to achieve 90% conversion of A?

# %%
# Answer here

# %% [markdown]
# ### How much total heat removal (in W) is necessary to maintain isothermal operation?

# %%
# Answer here

# %% [markdown]
# ### You decide the space time is much too large for your liking, so you insulate the PFR and try again. Plot conversion vs reactor space time assuming adiabatic operation.

# %%
# Answer here

# %% [markdown]
# ### What space time is needed to reach 90% conversion now?

# %%
# Answer here

# %% [markdown]
# ### What is the temperature of the exiting product stream?

# %%
# Answer here

# %% [markdown]
# ### Yikes, that's too hot! The solvent boils at that temperature. How could you operate the reactor, keeping conversion at 90%, and keeping maximum temperature $< 323$ K?

# %%
# Answer here

# %% [markdown]
# ### The boss still isn't happy. You decide to switch to a CSTR. What space time is necessary to achieve 90% conversion if you hold the CSTR isothermal at 300 K?

# %%
# Answer Here

# %% [markdown]
# ### At what rate do you have to remove heat to maintain that temperature?

# %%
# Answer Here

# %% [markdown]
# ### In the spirit of inquiry, and since you already have the insulation, you decide to test the CSTR adiabatically. Plot conversion vs space time.

# %%
# Answer Here

# %% [markdown]
# ### What space time is necessary to achieve 90% conversion now?

# %%
# Answer here

# %% [markdown]
# ### A colleague expresses concern that the CSTR might exhibit more than one steady state. Are the concerns valid? If so, what might you do to ameliorate them?

# %%
# Answer here

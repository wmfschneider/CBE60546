# %% [markdown]
# # Advanced Chemical Reaction Engieering (CBE 60546)
# ## Homework 2
# ## Due September 12, 2025

# %% [markdown]
# Carefully and neatly document your answers. You may use a mathematical solver like Jupyter/iPython. Use plotting software for all plots.

# %% [markdown]
# # Shale, shale everywhere
# ## Your nation has stumbled upon an enormous reserver of ethane (that's really true!), which you propose to use as a feedstock to produce ethylene, acetylene, and hydrogen via thermal dehydrogenation:
# $\ce{C2H6(g) -> C2H4(g) + H2(g)}$ \
# $\ce{C2H6(g) -> C2H2(g) + 2H2(g)}$
#
# ## The thermodynamic data [here](https://github.com/wmfschneider/CBE60546/blob/main/Homework/HW2-thermo.csv) is from the [CRC Handbook](https://onesearch.library.nd.edu/permalink/f/1phik6l/ndu_aleph002720619), and is based on 1 bar standard state. All the gases can be considered to be ideal over the range of interest here.

# %% [markdown]
# ### Plot the standard state enthalpy of ethane vs $T$ from 600 to 1200 K. What does the slope of the plot correspond to?

# %%
# Answer Here

# %% [markdown]
# ### Is the slope positive or negative? Why?

# %%
# Answer here

# %% [markdown]
# ### Plot the standard state entropy of ethane vs $T$ from 600 to 1200 K.

# %%
# Answer here

# %% [markdown]
# ### Is the slope positive or negative? Why?

# %%
# Answer here

# %% [markdown]
# ### Consider the ethane to ethylene reaction. What do you expect for the sign of $\Delta H^\circ$, $\Delta S^\circ$, and $\Delta G^\circ$? Why?

# %%
# Answer Here

# %% [markdown]
# ### Plot the standard state reaction enthalpy, $T$ times the standard state reaction entropy, and the standard state reaction Gibbs energy vs $T$ from 600 to 1200 K.

# %%
# Answer Here

# %% [markdown]
# ### What do the plots tell you about the conditions necessary to run this reaction thermally? About what contributes to the free energy change with $T$?

# %%
# Answer Here

# %% [markdown]
# ### Plot the free energy of the ethane to ethylene reaction vs ethane conversion at 800, 1000, and 1200K and 1 bar. Determine the equilibrium conversion of ethane at each temperature if this was the only reaction to occur.

# %%
# Answer Here

# %% [markdown]
# ### Imagine a semi-permeable membrane through which you could control the partial pressure (chemical potential) of hydrogen in a reaction vessel. Plot the mole fractions of ethane and ethylene as a function of $\ln P_{H_2}$ at 1000K. (Assume the H$_2$ does not contribute to the total moles in the vessel.)

# %%
# Answer Here

# %% [markdown]
# ### Now consider both reactions simultaneously. Determine the equilibrium ratio of ethylene to acetylene, starting from pure ethane, at 1000 K and 1, 10, and 100 bar total pressure (again, assume ideal behavior at all conditions). Can you explain the result?

# %%
# Answer Here

# %% [markdown]
# # NOx, NOx, who's there?
# ## A simple reaction of $\ce{NO}$ is it's oxidation to $\ce{NO2}$:
#
# $\ce{NO(g) + O2(g) -> NO2(g)}$
#
# ## You can assume all gases behave ideally under the conditions considered in this problem.

# %% [markdown]
# ### Determine $\Delta H^\circ(298~\text{K})$, $\Delta S^\circ(298~\text{K})$, $\Delta G^\circ(298~\text{K})$, and $K_p(298~\text{K})$ for the NO oxidation reaction (Don't forget to balance it first!). Be sure to specify your source and the standard state.

# %%
# Answer here

# %% [markdown]
# ### Calculate the equilibrium partial pressure ratio of $\ce{NO2}$ to $\ce{NO}$ in the atmosphere near the surface of the earth. Assume the mixing ratio of $\ce{O2}$ to be 0.2 and a temperature of $25^\circ$C.

# %%
# Answer here

# %% [markdown]
# ### From standard compilations and at 1 atm standard state, $\Delta H^\circ(250~\mathrm{K}) = -116.532~\mathrm{kJ~mol^{-1}}$ and $\Delta S^\circ(250~\mathrm{K}) = -152.179~\mathrm{J/mol/K}$. Use the van't Hoff relationship to plot $\Delta G^\circ(T)$ vs $T$ from room temperature to $1000^\circ$C. Add a point on your plot for the $\Delta G^\circ(298~\mathrm{K})$ you found from a tabulation.

# %%
# Answer here

# %% [markdown]
# ### NO oxidation is catalyzed over diesel oxidation catalysts (DOCs) on diesel vehicles. Plot the equilibrium conversion of $\ce{NO}$ to $\ce{NO2}$ vs $T$ from room temperature to $1000^\circ$C for an isobaric 1 atm reactor presented with 0.1% NO and 5% $\ce{O2}$, and balance $\ce{N2}$.

# %%
# Answer here

# %% [markdown]
# # Advanced Chemical Reaction Engineering (CBE 60546)
# ## Homework 7
# ## Due November 17, 2025

# %% [markdown]
# Carefully and neatly document your answers. Use Jupyter/Collab for all plots. See sample code at https://github.com/wmfschneider/CBE60546/blob/main/Resources/Examples.ipynb.

# %% [markdown]
# # Amalgamated amalgamated
# You work for *Amalgamated Cyanide Products*, which has as one of its major processes the reaction between aqueous hydrocyanic acid and aqueous acetaldehyde:
#
# $\ce{HCN (aq) + CH3CHO (aq) -> CH3CH(OH)CN (aq)}\ \ \ \ \ \ \ \ r = k C_{\ce{HCN}}C_{\ce{CH3CHO}}$
#
# where $k=0.5 M^{-1} s^{-1}$ at $25^\circ$. You need to make 100 kg/hr of product from from feed solutions of 0.80 M $\ce{HCN}$ and 1.0 M $\ce{CH3CHO}$, and do to the cost of the back-end separation, can tolerate no more than 0.02 M $\ce{HCN}$ in the product.

# %% [markdown]
# ### Determine the volumetric flow rates of your two reactants if you want to run the reaction stoichiometrically and meet your production target. Make a table of the inlet and outlet molar flow rates and inlet and outlet concentrations of all species.

# %%
# Answer Here

# %% [markdown]
# ### What size CSTR would you need, and what would be the average residence time in the reactor?

# %%
# Answer Here

# %% [markdown]
# ### What size PFR would you need, and what would be the residence time in the reactor?

# %%
# Answer here

# %% [markdown]
# ### A "Levenspiel" plot is a plot of $1/r$ vs conversion of a reactant. Create a Levenspiel plot to rationalize your answers above.

# %%
# Answer here

# %% [markdown]
# ### Your boss asks why you want to run in a CSTR rather than PFR. Give one good reason why.

# %%
# Answer here

# %% [markdown]
# ### The largest CSTR you can find is 1000 l in volume. At what temperature would you have to operate the reactor to achieve your production goal? The apparent activation energy of the reaction is 50 kJ/mol and you can assume the densities are independent of temperature.

# %%
# Answer here

# %% [markdown]
# ### (BONUS) A bright colleague suggests that the reaction could be run more effectively in a gas-phase, isobaric (constant pressure), isothermal PFR with no diluent. The gas-phase reaction follows the same rate law and has the same rate constant at $200^\circ$ that the aqueous reaction has at $25^\circ$. What size PFR would you need and at what space velocity would you need to operate it? You can treat all the gases as ideal. (*Hint* Because the reaction takes two molecules to one, the volumetric flow rate must increase down the reactor to maintain constant pressure. You will need to incorporate this change in the calculation of concentration as reaction progresses.)

# %%
# Answer here

# %% [markdown]
# ### The PFR idea was a bust, your colleague was fired, and you get the budget to buy the CSTR you want. You propose to fill the reactor with water before starting to flow in reactants. How long will you have to wait for effluent concentrations to reach 90% of steady-state?

# %%
# Answer here

# %% [markdown]
# # On autopilot
# An autocatalytic reaction is one in which a reaction product catalyzes the formation of more product. Many biological processes, for instance, are autocatalytic. You are designing a reactor for the autocatalytic, solution-phase, constant-density reaction:
#
# $\ce{2 A -> B}\ \ \ \ \ \ \ \ r=kC_AC_B\ \ \ \ \ \ \ \ \ k=0.5 \text{M}^{-1}\text{s}^{-1}$
#
# starting from 2.0 M solution of A and producing 1 mol/s of 0.9 M B.

# %% [markdown]
# ### Determine the reactor volume and residence time necessary to run the reaction in a CSTR.

# %%
# Answer Here

# %% [markdown]
# ### Same question, PFR.

# %%
# Answer Here

# %% [markdown]
# ### Suppose you want to minimize total reactor volume by staging a PFR and CSTR in series. In which order should you put the reactors, and what reactor volumes should you choose?

# %%
# Answer Here

# %% [markdown]
# # Trade-offs
# A 1 M solution of reactant A is used to make B in an isothermal, constant density reactor. Unfortunately, the reaction also makes an undesired product D. The reaction sequence and kinetics are:
#
# $\ce{2 A -> B}\ \ \ \ \ \ \ r_1=k_1C_A^2$
# $\ce{A + B-> D}\ \ \ \ \ \ \ r_2=k_2C_AC_B$
#
# where $k_1 = k_2 = 0.2 \text{M}^{-1}\text{s}^{-1}$.

# %% [markdown]
# ### Plot the concentrations of all species vs residence time up to 10 min assuming the reaction is run in a PFR.

# %%
# Answer Here

# %% [markdown]
# ### Plot the concentrations of all species vs residence time up to 10 min assuming the reaction is run in a CSTR.

# %%
# Answer Here

# %% [markdown]
# ### Which reactor would you choose if you want to maximine the *yield* of B?

# %%
# Answer here

# %% [markdown]
# ### Which reactor would you choose if you want to maximine the *selectivity* torwards B?

# %%
# Answer here

# %% [markdown]
# # Advanced Chemical Reaction Engieering (CBE 60546)
# ## Homework 4
# ## Due October 6, 2025

# %% [markdown]
# Carefully and neatly document your answers. Use Jupyter/Collab for all plots. See sample code at https://github.com/wmfschneider/CBE60546/blob/main/Resources/Examples.ipynb.

# %% [markdown]
# # Its elementary, realy ...

# %% [markdown]
# ### Which of the following reactions can be assumed to be elementary? If it is elementary, indicate the molecularity. Briefly Justify your answers.
#
# $$\ce{ O3(g) -> O2(g) + O(g)}$$
# $$\ce{ 2H2(g) + O2(g) -> H2O(g)}$$
# $$\ce{ 2NO(g) + O2(g) -> 2NO2(g)}$$
# $$\ce{ H* + I2 -> HI + I*}$$
# $$\ce{ Pt + H2(g) -> 2 Pt-H}$$
#
# In the last example, Pt indicates the surface of a Pt particle and $\ce{Pt-H}$ an H atom bound to the surface.

# %% [markdown]
# # The Path Less Traveled
# Chlorine monoxide, $\ce{ClO}$, exhibits three different self-reaction channels:
#
# |     | &emsp;&emsp;$A$ (L mol$^{-1}$s$^{-1}$)&emsp;&emsp; | &emsp;&emsp;$E_{a}$ (kJ mol$^{-1}$)&emsp;&emsp; |
# |:--------------------------------:|:----------------------------:|:-----------------------:|
# | $\ce{ClO* + ClO*->Cl2 + O2}$     | $ 6.08\times10^{8}   $       |      $13.2$             |
# | $\ce{ClO* + ClO*->Cl* + ClOO}$   | $ 1.79\times10^{10}  $       |      $20.4$             |
# | $\ce{ClO* + ClO*->Cl* + OClO}$   | $ 2.11\times10^{8}   $       |      $11.4$             |

# %% [markdown]
# ### Make Arrhenius plots of the three reactions from 150 to 500 K. Which reaction dominates at low temperature? At high temperature?

# %%
# Answer Here

# %% [markdown]
# ### Can collision theory account for the variations in rate constants amongst the three reactions? Why or why not?

# %%
# Answer Here

# %% [markdown]
# ### The rate constant for a gas-phase bimolecular reaction can be written within transition state theory (using an isobaric standard state) as shown below. Use the definition of $E_{a}$ to derive relationships between the Arrhenius parameters and the standard activation enthalpy, $\Delta H^{\circ,\ddagger}$ and standard activation entropy , $\Delta S^{\circ,\ddagger}$, at 1 bar standard state.
#
# $$ k = \frac{k_{b}T}{h}\left (\frac{RT}{P^{\circ}}\right )\exp\left(\frac{-\Delta G^{\circ,\ddagger}(T)}{k_{b}T}\right )$$

# %%
# Answer here

# %% [markdown]
# ### Calculate $\Delta H^{\circ,\ddagger}$ and $\Delta S^{\circ,\ddagger}$ of the three reactions.

# %%
# Answer Here

# %% [markdown]
# ### Using chemical intuition and the calculated $\Delta S^{\circ,\ddagger}$ as guides, draw candidate transition state structures for each of the three reactions. Include arrows to show motion along the reaction coordinates.

# %%
# Answer Here

# %% [markdown]
# ### Following is some thermodynamic data. Use it to sketch/dra/plot a potential enthalpy surface for the three reactions and a potential free energy surface for the three eactions at 298 K.
#
# |     |  &emsp;&emsp; $\Delta H^{\circ}_{f}(298K)$ (kJ mol$^{-1}$) &emsp;&emsp;  |  &emsp;&emsp; $\Delta S^{\circ}_{f}(298K)$ (J mol$^{-1}$) &emsp;&emsp;  |
# |:--------------------------------:|:----------------------------:|:-----------------------:|
# | $\ce{ClO*}$  |  $101.22$  |  $226.65$  |
# | $\ce{OClO*}$  |  $104.60$  |  $257.22$  |
# | $\ce{ClO2}$  |  $98.0$  |  $269.32$  |
# | $\ce{Cl}$  |  $121.3$  |  $165.19$  |
# | $\ce{Cl2}$  |  $0$  |  $223.08$  |
# | $\ce{O2}$  |  $0$  |  $205.15$  |

# %%
# Answer Here

# %% [markdown]
# # What do I get in compensation?
# Following are some observed data for the dehydrogenation of $\textit{iso}$-propanol, $\ce{CH3CH(OH)CH3 -> CH3C(O)CH3 + H2}$, over a series of catalysts:
#
# | &emsp;&emsp;$A$ (s$^{-1}$)&emsp;&emsp; | &emsp;&emsp;$E_{a}$ (kJ mol$^{-1}$)&emsp;&emsp; |
# |:----------------------------:|:-----------------------:|
# | $ 4.3\times10^{12}   $       |      $172$             |
# | $ 2.3\times10^{11}  $        |      $159$             |
# | $ 2.2\times10^{10}   $       |      $146$             |
# | $ 1.6\times10^{9}   $        |      $134$             |

# %% [markdown]
# ### What do you observe about the relationship between $\Delta H^{\circ,\ddagger}$ and $\Delta S^{\circ,\ddagger}$?

# %% [markdown]
# This relationship is called the "compensation effect," and its origins are widely debated.

# %% [markdown]
# ### Would you expect the rate of the reaction to be different for fully deuterated $\ce{CH3CH(OH)CH3}$? If so, would you expect it to be faster or slower? Why, in terms of rate constant parameters?

# %%
# Answer here

# %% [markdown]
# # It's too hot to stay here
# Temperature-programmed desorption is a common way to explore the kinetics of the subtraction or addition of a molecule to a surface. You are going to do experiments to compare the associative desorption of $\ce{N2}$ from a series of metal surfaces: $\ce{2N* -> N2 + 2 *}. You have the (DFT-derived) data below.

# %% [markdown]
# ![submitted.png](attachment:108a46d7-1c56-44f0-89df-027f63ca2341.png)

# %% [markdown]
# ### Consider the results for the metal terraces. Do they follow a BEP relationship? If so, what is the approximate slope? How about the steps? What can you conclude about how "early" or "late" the transition state is on each site type? How confident are you?

# %%
# Answer here

# %% [markdown]
# ### You prepare terraced surfaces of Re, Ru, and Ni with $\theta = 0.5$ ML of $\ce{N*}$ and perform temperature programmed desorption experiments starting at 300 K with a ramp rate of 5 K/s. Plot on the same graph the desorption rate vs temperature for each metal. Assume that the prefactor is a constant $10^{13}\mathrm{s}^{-1}$.

# %%
# Answer here

# %% [markdown]
# ### Ru is a good catalyst for the \ce{NH3} synthesis reaction, which involves the opposite, dissociative adsorption of \ce{N2} on a metal? Ru is a great catalyst for this reaction at the reaction temperature of about 750 K. Do the TPR results provide any useful insight into why Ru is a good choice?
